# %%
import os
import pandas as pd
covfilepath = r'G:\Data analysis\datasets\DownloadedDatasets\Covid19\Covid19_27052020_raw_data.csv'
dfraw = pd.read_csv(covfilepath, parse_dates=True)

# %%
dfraw.shape
# Out:
# (28183, 21)

# %%
dfraw.loc[dfraw.Nationality =='India'].shape
# Out:
# (2658, 21)

# %%
dfraw.loc[dfraw.Nationality =='India']
# Out:
#        Patient Number State Patient Number Date Announced  \
# 0                 1.0             KL-TS-P1     30/01/2020
# 1                 2.0             KL-AL-P1     02/02/2020
# 2                 3.0             KL-KS-P1     03/02/2020
# 3                 4.0                DL-P1     02/03/2020
# 4                 5.0                TS-P1     02/03/2020
# ...               ...                  ...            ...
# 24836         24779.0                  NaN     25/04/2020
# 24837         24780.0                  NaN     25/04/2020
# 24838         24781.0            KL-KL-P12     25/04/2020
# 24839         24782.0            KL-KL-P13     25/04/2020
# 24840         24783.0            KL-KL-P14     25/04/2020
#
#        Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                       NaN          20      F                  Thrissur
# 1                       NaN         NaN    NaN                 Alappuzha
# ...

# %% [markdown]
# To find out the status of community transmission, the type of transmission should be local.

# %%
dfraw.loc[(dfraw.Nationality =='India')&(dfraw['Type of transmission']=='Local')]
# Out:
#        Patient Number State Patient Number Date Announced  \
# 21               22.0                  NaN     04/03/2020
# 22               23.0                  NaN     04/03/2020
# 23               24.0                  NaN     04/03/2020
# 24               25.0                  NaN     04/03/2020
# 25               26.0                  NaN     04/03/2020
# ...               ...                  ...            ...
# 23320         23263.0                  NaN     24/04/2020
# 23321         23264.0                  NaN     24/04/2020
# 24836         24779.0                  NaN     25/04/2020
# 24838         24781.0            KL-KL-P12     25/04/2020
# 24840         24783.0            KL-KL-P14     25/04/2020
#
#        Estimated Onset Date Age Bracket Gender Detected City  \
# 21                      NaN         NaN      M          Agra
# 22                      NaN         NaN      F          Agra
# 23                      NaN          45      F          Agra
# ...

# %% [markdown]
# It turns out that out of 2658 patient records we have above in line 6, 705 have had local transmission. Above 27% of infected people are infected locally. 1 in 4 of all infected people have been infected locally.

# %%
dfraw.loc[(dfraw.Nationality =='India')&(dfraw['Type of transmission']=='Local')]

# %%
Cases reported from Mysore.

# %%
dfraw.loc[dfraw['Detected District']=='Mysuru']
# Out:
#        Patient Number State Patient Number Date Announced  \
# 324             325.0               KA-P20     21/03/2020
# 687             689.0               KA-P52     26/03/2020
# 1024           1013.0               KA-P77     29/03/2020
# 1025           1014.0               KA-P78     29/03/2020
# 1026           1015.0               KA-P79     29/03/2020
# ...               ...                  ...            ...
# 19030         18973.0              KA-P416     21/04/2020
# 19031         18974.0              KA-P417     21/04/2020
# 20553         20496.0              KA-P426     22/04/2020
# 20554         20497.0              KA-P427     22/04/2020
# 24906         24849.0              KA-P497     25/04/2020
#
#        Estimated Onset Date Age Bracket Gender Detected City  \
# 324                     NaN          35      M        Mysuru
# 687                     NaN          35      M           NaN
# 1024                    NaN          39      M     Nanjangud
# ...
